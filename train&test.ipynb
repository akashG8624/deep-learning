# %%
import pandas as pd 
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
X = df[['Age',"EstimatedSalary"]]
y = df['Purchased']

# %%
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
q = [[50,120000],[30,40000],[40,100000]]
model.predict(q)
# Out:
# C:\Users\Dhananjay\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1, 0, 1], dtype=int64)

# %%
sd = pd.read_csv("Obesity Classification.csv")
sd.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese

# %%
from sklearn.model_selection import train_test_split

sd["Gender"]=sd["Gender"].map({"Female":1,"Male":0})
X = sd[["Age","Gender","Height","Weight","BMI"]]
y = sd["Label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=30)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 0.8271604938271605
# 0.6666666666666666
# C:\Users\Dhananjay\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
ms = model.predict(X_test)
print(list(ms))
# Out:
# ['Normal Weight', 'Normal Weight', 'Underweight', 'Overweight', 'Underweight', 'Overweight', 'Obese', 'Underweight', 'Normal Weight', 'Overweight', 'Underweight', 'Underweight', 'Underweight', 'Underweight', 'Normal Weight', 'Underweight', 'Underweight', 'Normal Weight', 'Underweight', 'Underweight', 'Underweight', 'Obese', 'Normal Weight', 'Underweight', 'Underweight', 'Normal Weight', 'Overweight']

# %%
from sklearn.neighbors import KNeighborsClassifier
